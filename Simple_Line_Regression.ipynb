# %% [markdown]
# <a href="https://colab.research.google.com/github/Varanasi-Software-Junction/vsjcolab/blob/main/Simple_Line_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Simple Line Regression**
#
# [Documentation](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.linregress.html)
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
from scipy import stats
import matplotlib.pyplot as plt

# %%
x = [1,2,3]
y = [2,3,7]

slope, intercept, r, p, std_err = stats.linregress(x, y)
print("Slope=",slope,", Intercept=",intercept,", r =",r,",p=",p,"stderr=",std_err)
# Out:
# Slope= 2.5 , Intercept= -1.0 , r = 0.944911182523068 ,p= 0.2122956150096566 stderr= 0.8660254037844388

# %%
def linefunc(x):
  return slope * x + intercept

model = list(map(linefunc, x))
print("model",model)
print(r)
xvalue=10
predictedy=linefunc(xvalue)
print("Y=",predictedy)
plt.scatter(x, y)
plt.plot(x, model)
plt.show()
# Out:
# model [1.5, 4.0, 6.5]
# 0.944911182523068
# Y= 24.0
